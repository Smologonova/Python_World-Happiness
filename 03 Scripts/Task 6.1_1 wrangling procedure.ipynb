# %% [markdown]
# ### 01. Importing Libraries and Data

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Define path
path = r'C:\Users\iryna\Documents\Data analytics\Career foundry\6. Advanced Analytics & Dashboard Design\09-2022 World Happiness Analysis\02 Data'

# %%
# Import Data
hap2015 = pd.read_csv(os.path.join(path, 'Raw Data', '2015.csv'))

# %%
# Checking the output
hap2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# Import Data
hap2016 = pd.read_csv(os.path.join(path, 'Raw Data', '2016.csv'))
hap2017 = pd.read_csv(os.path.join(path, 'Raw Data', '2017.csv'))
hap2018 = pd.read_csv(os.path.join(path, 'Raw Data', '2018.csv'))
hap2019 = pd.read_csv(os.path.join(path, 'Raw Data', '2019.csv'))

# %%
hap2020 = pd.read_csv(os.path.join(path, 'Raw Data', '2020.csv'))
hap2021 = pd.read_csv(os.path.join(path, 'Raw Data', '2021.csv'))
hap2022 = pd.read_csv(os.path.join(path, 'Raw Data', '2022.csv'))

# %%
# Check the dimensions
hap2016.shape
# Out:
# (157, 13)

# %%
hap2017.shape
# Out:
# (155, 13)

# %%
hap2018.shape
# Out:
# (156, 10)

# %%
hap2019.shape
# Out:
# (156, 10)

# %%
hap2020.shape
# Out:
# (153, 20)

# %%
hap2021.shape
# Out:
# (149, 20)

# %%
hap2022.shape
# Out:
# (145, 13)

# %% [markdown]
# ### 02. Wrangling procedure

# %% [markdown]
# #### 02.1 Wrangling procedure - file year 2015

# %%
# 2015 checking the file
pd.options.display.max_columns = None
hap2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# 2015 dropping columns that are irrelevant for the analysis
hap2015.drop(columns = ['Standard Error'])
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %%
hap2015_2 = hap2015.drop(columns = ['Standard Error'])

# %%
# 2015 columns renaiming
hap2015_2.rename(columns={'Country' : 'country', 'Region' : 'region','Happiness Rank' : 'happiness_rank',
                        'Happiness Score' : 'happiness_score', 'Economy (GDP per Capita)' : 'economy_GDP_per_capita',
                       'Family' : 'family', 'Health (Life Expectancy)' : 'health_life_expectancy', 'Freedom' : 'freedom',
                       'Trust (Government Corruption)' : 'trust_government_corruption', 'Generosity' : 'generosity',
                       'Dystopia Residual' : 'dystopia_residual'}, inplace = True)

# %%
hap2015_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      158 non-null    object
#  1   region                       158 non-null    object
#  2   happiness_rank               158 non-null    int64
#  3   happiness_score              158 non-null    float64
#  4   economy_GDP_per_capita       158 non-null    float64
#  5   family                       158 non-null    float64
#  6   health_life_expectancy       158 non-null    float64
#  7   freedom                      158 non-null    float64
#  8   trust_government_corruption  158 non-null    float64
#  9   generosity                   158 non-null    float64
#  10  dystopia_residual            158 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.7+ KB

# %%
hap2015_2.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    economy_GDP_per_capita   family  health_life_expectancy  freedom  \
# 0                 1.39651  1.34951                 0.94143  0.66557
# 1                 1.30232  1.40223                 0.94784  0.62877
# 2                 1.32548  1.36058                 0.87464  0.64938
# 3                 1.45900  1.33095                 0.88521  0.66973
# 4                 1.32629  1.32261                 0.90563  0.63297
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                      0.41978     0.29678            2.51738
# ...

# %% [markdown]
# #### 02.2 Wrangling procedure - file year 2016

# %%
# 2016 checking the file
hap2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
# 2016 dropping columns that are irrelevant for the analysis
hap2016.drop(columns = ['Lower Confidence Interval', 'Upper Confidence Interval'])
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.526                   1.44178  1.16374
# 1              7.509                   1.52733  1.14524
# ...

# %%
hap2016_2 = hap2016.drop(columns = ['Lower Confidence Interval', 'Upper Confidence Interval'])

# %%
# 2016 columns renaiming
hap2016_2.rename(columns={'Country' : 'country', 'Region' : 'region','Happiness Rank' : 'happiness_rank',
                        'Happiness Score' : 'happiness_score', 'Economy (GDP per Capita)' : 'economy_GDP_per_capita',
                       'Family' : 'family', 'Health (Life Expectancy)' : 'health_life_expectancy', 'Freedom' : 'freedom',
                       'Trust (Government Corruption)' : 'trust_government_corruption', 'Generosity' : 'generosity',
                       'Dystopia Residual' : 'dystopia_residual'}, inplace = True)

# %%
hap2016_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      157 non-null    object
#  1   region                       157 non-null    object
#  2   happiness_rank               157 non-null    int64
#  3   happiness_score              157 non-null    float64
#  4   economy_GDP_per_capita       157 non-null    float64
#  5   family                       157 non-null    float64
#  6   health_life_expectancy       157 non-null    float64
#  7   freedom                      157 non-null    float64
#  8   trust_government_corruption  157 non-null    float64
#  9   generosity                   157 non-null    float64
#  10  dystopia_residual            157 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.6+ KB

# %%
hap2016_2.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    economy_GDP_per_capita   family  health_life_expectancy  freedom  \
# 0                 1.44178  1.16374                 0.79504  0.57941
# 1                 1.52733  1.14524                 0.86303  0.58557
# 2                 1.42666  1.18326                 0.86733  0.56624
# 3                 1.57744  1.12690                 0.79579  0.59609
# 4                 1.40598  1.13464                 0.81091  0.57104
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                      0.44453     0.36171            2.73939
# ...

# %% [markdown]
# #### 02.3 Wrangling procedure - file year 2017

# %%
# 2017 checking the file
hap2017.head()
# Out:
#        Country          Region  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0       Norway  Western Europe               1            7.537      7.594445
# 1      Denmark  Western Europe               2            7.522      7.581728
# 2      Iceland  Western Europe               3            7.504      7.622030
# 3  Switzerland  Western Europe               4            7.494      7.561772
# 4      Finland  Western Europe               5            7.469      7.527542
#
#    Whisker.low  Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.  \
# 0     7.479556                  1.616463  1.533524                  0.796667
# 1     7.462272                  1.482383  1.551122                  0.792566
# 2     7.385970                  1.480633  1.610574                  0.833552
# 3     7.426227                  1.564980  1.516912                  0.858131
# 4     7.410458                  1.443572  1.540247                  0.809158
#
# ...

# %%
# 2017 dropping columns that are irrelevant for the analysis
hap2017.drop(columns = ['Whisker.high', 'Whisker.low'])
# Out:
#                       Country                        Region  Happiness.Rank  \
# 0                      Norway                Western Europe               1
# 1                     Denmark                Western Europe               2
# 2                     Iceland                Western Europe               3
# 3                 Switzerland                Western Europe               4
# 4                     Finland                Western Europe               5
# ..                        ...                           ...             ...
# 150                    Rwanda            Sub-Saharan Africa             151
# 151                     Syria  Middle East and North Africa             152
# 152                  Tanzania            Sub-Saharan Africa             153
# 153                   Burundi            Sub-Saharan Africa             154
# 154  Central African Republic            Sub-Saharan Africa             155
#
# ...

# %%
hap2017_2 = hap2017.drop(columns = ['Whisker.high', 'Whisker.low'])

# %%
# 2017 columns renaiming
hap2017_2.rename(columns={'Country' : 'country', 'Region' : 'region','Happiness.Rank' : 'happiness_rank',
                        'Happiness.Score' : 'happiness_score', 'Economy..GDP.per.Capita.' : 'economy_GDP_per_capita',
                       'Family' : 'family', 'Health..Life.Expectancy.' : 'health_life_expectancy', 'Freedom' : 'freedom',
                       'Trust..Government.Corruption.' : 'trust_government_corruption', 'Generosity' : 'generosity',
                       'Dystopia.Residual' : 'dystopia_residual'}, inplace = True)

# %%
hap2017_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      155 non-null    object
#  1   region                       155 non-null    object
#  2   happiness_rank               155 non-null    int64
#  3   happiness_score              155 non-null    float64
#  4   economy_GDP_per_capita       155 non-null    float64
#  5   family                       155 non-null    float64
#  6   health_life_expectancy       155 non-null    float64
#  7   freedom                      155 non-null    float64
#  8   generosity                   155 non-null    float64
#  9   trust_government_corruption  155 non-null    float64
#  10  dystopia_residual            155 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.4+ KB

# %%
# 2017 shift column 'generocity' before 'dystopia_residual' for cinsistency
ninth_column=hap2017_2.pop('generosity')

# %%
# 2017 insert column using insert(position,column_name, ninth_column) function
hap2017_2.insert(9, 'generosity', ninth_column)
hap2017_2.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0       Norway  Western Europe               1            7.537
# 1      Denmark  Western Europe               2            7.522
# 2      Iceland  Western Europe               3            7.504
# 3  Switzerland  Western Europe               4            7.494
# 4      Finland  Western Europe               5            7.469
#
#    economy_GDP_per_capita    family  health_life_expectancy   freedom  \
# 0                1.616463  1.533524                0.796667  0.635423
# 1                1.482383  1.551122                0.792566  0.626007
# 2                1.480633  1.610574                0.833552  0.627163
# 3                1.564980  1.516912                0.858131  0.620071
# 4                1.443572  1.540247                0.809158  0.617951
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                     0.315964    0.362012           2.277027
# ...

# %%
hap2017_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      155 non-null    object
#  1   region                       155 non-null    object
#  2   happiness_rank               155 non-null    int64
#  3   happiness_score              155 non-null    float64
#  4   economy_GDP_per_capita       155 non-null    float64
#  5   family                       155 non-null    float64
#  6   health_life_expectancy       155 non-null    float64
#  7   freedom                      155 non-null    float64
#  8   trust_government_corruption  155 non-null    float64
#  9   generosity                   155 non-null    float64
#  10  dystopia_residual            155 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.4+ KB

# %% [markdown]
# #### 02.4 Wrangling procedure - file year 2018

# %%
# 2018 checking the file
hap2018.head()
# Out:
#        Country          Region  Happiness rank  Score  GDP per capita  \
# 0      Finland  Western Europe               1  7.632           1.305
# 1       Norway  Western Europe               2  7.594           1.456
# 2      Denmark  Western Europe               3  7.555           1.351
# 3      Iceland  Western Europe               4  7.495           1.343
# 4  Switzerland  Western Europe               5  7.487           1.420
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.592                    0.874                         0.681
# 1           1.582                    0.861                         0.686
# 2           1.590                    0.868                         0.683
# 3           1.644                    0.914                         0.677
# 4           1.549                    0.927                         0.660
#
#    Generosity  Perceptions of corruption
# 0       0.202                      0.393
# ...

# %%
# 2018 Using DataFrame.insert() to add a column
hap2018.insert(10, 'dystopia_residual', 0)

# %%
hap2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       156 non-null    object
#  1   Region                        156 non-null    object
#  2   Happiness rank                156 non-null    int64
#  3   Score                         156 non-null    float64
#  4   GDP per capita                156 non-null    float64
#  5   Social support                156 non-null    float64
#  6   Healthy life expectancy       156 non-null    float64
#  7   Freedom to make life choices  156 non-null    float64
#  8   Generosity                    156 non-null    float64
#  9   Perceptions of corruption     155 non-null    float64
#  10  dystopia_residual             156 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %%
# 2018 columns renaiming
hap2018.rename(columns={'Country' : 'country', 'Region' : 'region','Happiness rank' : 'happiness_rank',
                        'Score' : 'happiness_score', 'GDP per capita' : 'economy_GDP_per_capita',
                       'Social support' : 'family', 'Healthy life expectancy' : 'health_life_expectancy', 'Freedom to make life choices' : 'freedom',
                       'Perceptions of corruption' : 'trust_government_corruption', 'Generosity' : 'generosity'}, inplace = True)

# %%
hap2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      156 non-null    object
#  1   region                       156 non-null    object
#  2   happiness_rank               156 non-null    int64
#  3   happiness_score              156 non-null    float64
#  4   economy_GDP_per_capita       156 non-null    float64
#  5   family                       156 non-null    float64
#  6   health_life_expectancy       156 non-null    float64
#  7   freedom                      156 non-null    float64
#  8   generosity                   156 non-null    float64
#  9   trust_government_corruption  155 non-null    float64
#  10  dystopia_residual            156 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %%
# 2018 shift column 'generocity' before 'dystopia_residual' for cinsistency
ninth_column=hap2018.pop('generosity')

# %%
# 2018 insert column using insert(position,column_name, ninth_column) function
hap2018.insert(9, 'generosity', ninth_column)
hap2018.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0      Finland  Western Europe               1            7.632
# 1       Norway  Western Europe               2            7.594
# 2      Denmark  Western Europe               3            7.555
# 3      Iceland  Western Europe               4            7.495
# 4  Switzerland  Western Europe               5            7.487
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.305   1.592                   0.874    0.681
# 1                   1.456   1.582                   0.861    0.686
# 2                   1.351   1.590                   0.868    0.683
# 3                   1.343   1.644                   0.914    0.677
# 4                   1.420   1.549                   0.927    0.660
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                        0.393       0.202                  0
# ...

# %% [markdown]
# #### 02.5 Wrangling procedure - file year 2019

# %%
# 2019 checking the file
hap2019.head()
# Out:
#        Country          Region  Happiness rank  Score  GDP per capita  \
# 0      Finland  Western Europe               1  7.769           1.340
# 1      Denmark  Western Europe               2  7.600           1.383
# 2       Norway  Western Europe               3  7.554           1.488
# 3      Iceland  Western Europe               4  7.494           1.380
# 4  Netherlands  Western Europe               5  7.488           1.396
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.587                    0.986                         0.596
# 1           1.573                    0.996                         0.592
# 2           1.582                    1.028                         0.603
# 3           1.624                    1.026                         0.591
# 4           1.522                    0.999                         0.557
#
#    Generosity  Perceptions of corruption
# 0       0.153                      0.393
# ...

# %%
# 2019 Using DataFrame.insert() to add a column
hap2019.insert(10, 'dystopia_residual', 0)

# %%
hap2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       156 non-null    object
#  1   Region                        156 non-null    object
#  2   Happiness rank                156 non-null    int64
#  3   Score                         156 non-null    float64
#  4   GDP per capita                156 non-null    float64
#  5   Social support                156 non-null    float64
#  6   Healthy life expectancy       156 non-null    float64
#  7   Freedom to make life choices  156 non-null    float64
#  8   Generosity                    156 non-null    float64
#  9   Perceptions of corruption     156 non-null    float64
#  10  dystopia_residual             156 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %%
# 2019 columns renaiming
hap2019.rename(columns={'Country' : 'country', 'Region' : 'region','Happiness rank' : 'happiness_rank',
                        'Score' : 'happiness_score', 'GDP per capita' : 'economy_GDP_per_capita',
                       'Social support' : 'family', 'Healthy life expectancy' : 'health_life_expectancy', 'Freedom to make life choices' : 'freedom',
                       'Perceptions of corruption' : 'trust_government_corruption', 'Generosity' : 'generosity'}, inplace = True)

# %%
hap2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      156 non-null    object
#  1   region                       156 non-null    object
#  2   happiness_rank               156 non-null    int64
#  3   happiness_score              156 non-null    float64
#  4   economy_GDP_per_capita       156 non-null    float64
#  5   family                       156 non-null    float64
#  6   health_life_expectancy       156 non-null    float64
#  7   freedom                      156 non-null    float64
#  8   generosity                   156 non-null    float64
#  9   trust_government_corruption  156 non-null    float64
#  10  dystopia_residual            156 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 13.5+ KB

# %%
# 2019 shift column 'generocity' before 'dystopia_residual' for cinsistency
ninth_column=hap2019.pop('generosity')

# %%
# 2019 insert column using insert(position,column_name, ninth_column) function
hap2019.insert(9, 'generosity', ninth_column)
hap2019.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0      Finland  Western Europe               1            7.769
# 1      Denmark  Western Europe               2            7.600
# 2       Norway  Western Europe               3            7.554
# 3      Iceland  Western Europe               4            7.494
# 4  Netherlands  Western Europe               5            7.488
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.340   1.587                   0.986    0.596
# 1                   1.383   1.573                   0.996    0.592
# 2                   1.488   1.582                   1.028    0.603
# 3                   1.380   1.624                   1.026    0.591
# 4                   1.396   1.522                   0.999    0.557
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                        0.393       0.153                  0
# ...

# %% [markdown]
# #### 02.6 Wrangling procedure - file year 2020

# %%
# 2020 checking the file
hap2020.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
# 2020 dropping columns that are irrelevant for the analysis
hap2020.drop(columns = ['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
                       'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
                       'Perceptions of corruption', 'Ladder score in Dystopia'])
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 0                            1.285190                      1.499526
# ...

# %%
hap2020_2 = hap2020.drop(columns = ['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
                       'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
                       'Perceptions of corruption', 'Ladder score in Dystopia'])

# %%
# 2020 columns renaiming
hap2020_2.rename(columns={'Country name' : 'country', 'Regional indicator' : 'region',
                        'Ladder score' : 'happiness_score', 'Explained by: Log GDP per capita' : 'economy_GDP_per_capita',
                       'Explained by: Social support' : 'family', 'Explained by: Healthy life expectancy' : 'health_life_expectancy', 'Explained by: Freedom to make life choices' : 'freedom',
                       'Explained by: Perceptions of corruption' : 'trust_government_corruption', 'Explained by: Generosity' : 'generosity',
                       'Dystopia + residual' : 'dystopia_residual'}, inplace = True)

# %%
hap2020_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      153 non-null    object
#  1   region                       153 non-null    object
#  2   happiness_score              153 non-null    float64
#  3   economy_GDP_per_capita       153 non-null    float64
#  4   family                       153 non-null    float64
#  5   health_life_expectancy       153 non-null    float64
#  6   freedom                      153 non-null    float64
#  7   generosity                   153 non-null    float64
#  8   trust_government_corruption  153 non-null    float64
#  9   dystopia_residual            153 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 12.1+ KB

# %%
# 2020 creating a cloumn 'happiness_rank'
hap2020_2['happiness_rank']=hap2020_2['happiness_score'].rank(ascending=False)
hap2020_2=hap2020_2.sort_values(by='happiness_rank', ignore_index=True)
hap2020_2
# Out:
#                       country              region  happiness_score  \
# 0                     Finland      Western Europe           7.8087
# 1                     Denmark      Western Europe           7.6456
# 2                 Switzerland      Western Europe           7.5599
# 3                     Iceland      Western Europe           7.5045
# 4                      Norway      Western Europe           7.4880
# ..                        ...                 ...              ...
# 148  Central African Republic  Sub-Saharan Africa           3.4759
# 149                    Rwanda  Sub-Saharan Africa           3.3123
# 150                  Zimbabwe  Sub-Saharan Africa           3.2992
# 151               South Sudan  Sub-Saharan Africa           2.8166
# 152               Afghanistan          South Asia           2.5669
#
#      economy_GDP_per_capita    family  health_life_expectancy   freedom  \
# 0                  1.285190  1.499526                0.961271  0.662317
# ...

# %%
hap2020_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      153 non-null    object
#  1   region                       153 non-null    object
#  2   happiness_score              153 non-null    float64
#  3   economy_GDP_per_capita       153 non-null    float64
#  4   family                       153 non-null    float64
#  5   health_life_expectancy       153 non-null    float64
#  6   freedom                      153 non-null    float64
#  7   generosity                   153 non-null    float64
#  8   trust_government_corruption  153 non-null    float64
#  9   dystopia_residual            153 non-null    float64
#  10  happiness_rank               153 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 13.3+ KB

# %%
# 2020 converting 'happiness_rank' from float to int
hap2020_2['happiness_rank'] = hap2020_2['happiness_rank'].apply(np.int64)

# %%
hap2020_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      153 non-null    object
#  1   region                       153 non-null    object
#  2   happiness_score              153 non-null    float64
#  3   economy_GDP_per_capita       153 non-null    float64
#  4   family                       153 non-null    float64
#  5   health_life_expectancy       153 non-null    float64
#  6   freedom                      153 non-null    float64
#  7   generosity                   153 non-null    float64
#  8   trust_government_corruption  153 non-null    float64
#  9   dystopia_residual            153 non-null    float64
#  10  happiness_rank               153 non-null    int64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.3+ KB

# %%
# 2020 shift columns 'generocity' and 'happiness_rank' for cinsistency
third_column=hap2020_2.pop('happiness_rank')
ninth_column=hap2020_2.pop('generosity')

# %%
# 2020 insert column using insert(position,column_name, ninth_column) function
hap2020_2.insert(2, 'happiness_rank', third_column)
hap2020_2.insert(9, 'generosity', ninth_column)
hap2020_2.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0      Finland  Western Europe               1           7.8087
# 1      Denmark  Western Europe               2           7.6456
# 2  Switzerland  Western Europe               3           7.5599
# 3      Iceland  Western Europe               4           7.5045
# 4       Norway  Western Europe               5           7.4880
#
#    economy_GDP_per_capita    family  health_life_expectancy   freedom  \
# 0                1.285190  1.499526                0.961271  0.662317
# 1                1.326949  1.503449                0.979333  0.665040
# 2                1.390774  1.472403                1.040533  0.628954
# 3                1.326502  1.547567                1.000843  0.661981
# 4                1.424207  1.495173                1.008072  0.670201
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                     0.477857    0.159670           2.762835
# ...

# %% [markdown]
# #### 02.7 Wrangling procedure - file year 2021

# %%
# 2021 checking the file
hap2021.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# 2021 dropping columns that are irrelevant for the analysis
hap2021.drop(columns = ['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
                       'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
                       'Perceptions of corruption', 'Ladder score in Dystopia'])
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 0                               1.446                         1.106
# 1                               1.502                         1.108
# 2                               1.566                         1.079
# 3                               1.482                         1.172
# ...

# %%
hap2021_2 = hap2021.drop(columns = ['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Logged GDP per capita',
                       'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
                       'Perceptions of corruption', 'Ladder score in Dystopia'])

# %%
# 2021 columns renaiming
hap2021_2.rename(columns={'Country name' : 'country', 'Regional indicator' : 'region',
                        'Ladder score' : 'happiness_score', 'Explained by: Log GDP per capita' : 'economy_GDP_per_capita',
                       'Explained by: Social support' : 'family', 'Explained by: Healthy life expectancy' : 'health_life_expectancy', 'Explained by: Freedom to make life choices' : 'freedom',
                       'Explained by: Perceptions of corruption' : 'trust_government_corruption', 'Explained by: Generosity' : 'generosity',
                       'Dystopia + residual' : 'dystopia_residual'}, inplace = True)

# %%
hap2021_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      149 non-null    object
#  1   region                       149 non-null    object
#  2   happiness_score              149 non-null    float64
#  3   economy_GDP_per_capita       149 non-null    float64
#  4   family                       149 non-null    float64
#  5   health_life_expectancy       149 non-null    float64
#  6   freedom                      149 non-null    float64
#  7   generosity                   149 non-null    float64
#  8   trust_government_corruption  149 non-null    float64
#  9   dystopia_residual            149 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 11.8+ KB

# %%
# 2021 creating a cloumn 'happiness_rank'
hap2021_2['happiness_rank']=hap2021_2['happiness_score'].rank(ascending=False)
hap2021_2=hap2021_2.sort_values(by='happiness_rank', ignore_index=True)
hap2021_2
# Out:
#          country              region  happiness_score  economy_GDP_per_capita  \
# 0        Finland      Western Europe            7.842                   1.446
# 1        Denmark      Western Europe            7.620                   1.502
# 2    Switzerland      Western Europe            7.571                   1.566
# 3        Iceland      Western Europe            7.554                   1.482
# 4    Netherlands      Western Europe            7.464                   1.501
# ..           ...                 ...              ...                     ...
# 144      Lesotho  Sub-Saharan Africa            3.512                   0.451
# 145     Botswana  Sub-Saharan Africa            3.467                   1.099
# 146       Rwanda  Sub-Saharan Africa            3.415                   0.364
# 147     Zimbabwe  Sub-Saharan Africa            3.145                   0.457
# 148  Afghanistan          South Asia            2.523                   0.370
#
# ...

# %%
hap2021_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      149 non-null    object
#  1   region                       149 non-null    object
#  2   happiness_score              149 non-null    float64
#  3   economy_GDP_per_capita       149 non-null    float64
#  4   family                       149 non-null    float64
#  5   health_life_expectancy       149 non-null    float64
#  6   freedom                      149 non-null    float64
#  7   generosity                   149 non-null    float64
#  8   trust_government_corruption  149 non-null    float64
#  9   dystopia_residual            149 non-null    float64
#  10  happiness_rank               149 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 12.9+ KB

# %%
# 2021 converting 'happiness_rank' from float to int
hap2021_2['happiness_rank'] = hap2021_2['happiness_rank'].apply(np.int64)

# %%
hap2021_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      149 non-null    object
#  1   region                       149 non-null    object
#  2   happiness_score              149 non-null    float64
#  3   economy_GDP_per_capita       149 non-null    float64
#  4   family                       149 non-null    float64
#  5   health_life_expectancy       149 non-null    float64
#  6   freedom                      149 non-null    float64
#  7   generosity                   149 non-null    float64
#  8   trust_government_corruption  149 non-null    float64
#  9   dystopia_residual            149 non-null    float64
#  10  happiness_rank               149 non-null    int64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 12.9+ KB

# %%
# 2021 shift columns 'generocity' and 'happiness_rank' for cinsistency
third_column=hap2021_2.pop('happiness_rank')
ninth_column=hap2021_2.pop('generosity')

# %%
# 2021 insert column using insert(position,column_name, ninth_column) function
hap2021_2.insert(2, 'happiness_rank', third_column)
hap2021_2.insert(9, 'generosity', ninth_column)
hap2021_2.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0      Finland  Western Europe               1            7.842
# 1      Denmark  Western Europe               2            7.620
# 2  Switzerland  Western Europe               3            7.571
# 3      Iceland  Western Europe               4            7.554
# 4  Netherlands  Western Europe               5            7.464
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.446   1.106                   0.741    0.691
# 1                   1.502   1.108                   0.763    0.686
# 2                   1.566   1.079                   0.816    0.653
# 3                   1.482   1.172                   0.772    0.698
# 4                   1.501   1.079                   0.753    0.647
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                        0.481       0.124              3.253
# ...

# %% [markdown]
# #### 02.8 Wrangling procedure - file year 2022

# %%
# 2022 checking the file
hap2022.head()
# Out:
#    RANK      Country          Region Happiness score Whisker-high Whisker-low  \
# 0     1      Finland  Western Europe           7,821        7,886       7,756
# 1     2      Denmark  Western Europe           7,636        7,710       7,563
# 2     3      Iceland  Western Europe           7,557        7,651       7,464
# 3     4  Switzerland  Western Europe           7,512        7,586       7,437
# 4     5  Netherlands  Western Europe           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# ...

# %%
# 2022 dropping columns that are irrelevant for the analysis
hap2022.drop(columns = ['Whisker-high', 'Whisker-low'])
# Out:
#      RANK      Country                        Region Happiness score  \
# 0       1      Finland                Western Europe           7,821
# 1       2      Denmark                Western Europe           7,636
# 2       3      Iceland                Western Europe           7,557
# 3       4  Switzerland                Western Europe           7,512
# 4       5  Netherlands                Western Europe           7,415
# ..    ...          ...                           ...             ...
# 140   141     Botswana            Sub-Saharan Africa           3,471
# 141   142       Rwanda            Sub-Saharan Africa           3,268
# 142   143     Zimbabwe            Sub-Saharan Africa           2,995
# 143   144      Lebanon  Middle East and North Africa           2,955
# 144   145  Afghanistan                    South Asia           2,404
#
#     Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                        2,518                        1,892
# ...

# %%
hap2022_2 = hap2022.drop(columns = ['Whisker-high', 'Whisker-low'])

# %%
# 2022 columns renaiming
hap2022_2.rename(columns={'RANK' : 'happiness_rank', 'Country' : 'country', 'Region' : 'region',
                        'Happiness score' : 'happiness_score', 'Explained by: GDP per capita' : 'economy_GDP_per_capita',
                       'Explained by: Social support' : 'family', 'Explained by: Healthy life expectancy' : 'health_life_expectancy', 'Explained by: Freedom to make life choices' : 'freedom',
                       'Explained by: Perceptions of corruption' : 'trust_government_corruption', 'Explained by: Generosity' : 'generosity',
                       'Dystopia (1.83) + residual' : 'dystopia_residual'}, inplace = True)

# %%
hap2022_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   happiness_rank               145 non-null    int64
#  1   country                      145 non-null    object
#  2   region                       145 non-null    object
#  3   happiness_score              145 non-null    object
#  4   dystopia_residual            145 non-null    object
#  5   economy_GDP_per_capita       145 non-null    object
#  6   family                       145 non-null    object
#  7   health_life_expectancy       145 non-null    object
#  8   freedom                      145 non-null    object
#  9   generosity                   145 non-null    object
#  10  trust_government_corruption  145 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 12.6+ KB

# %%
hap2022_2.head()
# Out:
#    happiness_rank      country          region happiness_score  \
# 0               1      Finland  Western Europe           7,821
# 1               2      Denmark  Western Europe           7,636
# 2               3      Iceland  Western Europe           7,557
# 3               4  Switzerland  Western Europe           7,512
# 4               5  Netherlands  Western Europe           7,415
#
#   dystopia_residual economy_GDP_per_capita family health_life_expectancy  \
# 0             2,518                  1,892  1,258                  0,775
# 1             2,226                  1,953  1,243                  0,777
# 2             2,320                  1,936  1,320                  0,803
# 3             2,153                  2,026  1,226                  0,822
# 4             2,137                  1,945  1,206                  0,787
#
#   freedom generosity trust_government_corruption
# 0   0,736      0,109                       0,534
# ...

# %%
# 2022 shift columns 'dystopia_residual', generocity' and 'happiness_rank' for cinsistency
third_column=hap2022_2.pop('happiness_rank')
ninth_column=hap2022_2.pop('generosity')
tenth_column=hap2022_2.pop('dystopia_residual')

# %%
# 2022 insert column using insert(position,column_name, column) function
hap2022_2.insert(2, 'happiness_rank', third_column)
hap2022_2.insert(9, 'generosity', ninth_column)
hap2022_2.insert(10, 'dystopia_residual', tenth_column)
hap2022_2.head()
# Out:
#        country          region  happiness_rank happiness_score  \
# 0      Finland  Western Europe               1           7,821
# 1      Denmark  Western Europe               2           7,636
# 2      Iceland  Western Europe               3           7,557
# 3  Switzerland  Western Europe               4           7,512
# 4  Netherlands  Western Europe               5           7,415
#
#   economy_GDP_per_capita family health_life_expectancy freedom  \
# 0                  1,892  1,258                  0,775   0,736
# 1                  1,953  1,243                  0,777   0,719
# 2                  1,936  1,320                  0,803   0,718
# 3                  2,026  1,226                  0,822   0,677
# 4                  1,945  1,206                  0,787   0,651
#
#   trust_government_corruption generosity dystopia_residual
# 0                       0,534      0,109             2,518
# 1                       0,532      0,188             2,226
# ...

# %% [markdown]
# #### 03. Creating a new column 'Year' for each file

# %%
# 2015 Using DataFrame.insert() to add a column
hap2015_2.insert(2, 'Year', 2015)

# %%
# Observe the result
hap2015_2.head()
# Out:
#        country          region  Year  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe  2015               1            7.587
# 1      Iceland  Western Europe  2015               2            7.561
# 2      Denmark  Western Europe  2015               3            7.527
# 3       Norway  Western Europe  2015               4            7.522
# 4       Canada   North America  2015               5            7.427
#
#    economy_GDP_per_capita   family  health_life_expectancy  freedom  \
# 0                 1.39651  1.34951                 0.94143  0.66557
# 1                 1.30232  1.40223                 0.94784  0.62877
# 2                 1.32548  1.36058                 0.87464  0.64938
# 3                 1.45900  1.33095                 0.88521  0.66973
# 4                 1.32629  1.32261                 0.90563  0.63297
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                      0.41978     0.29678            2.51738
# ...

# %%
hap2015_2['Year'].value_counts(dropna=False)
# Out:
# 2015    158
# Name: Year, dtype: int64

# %%
# 2016 Using DataFrame.insert() to add a column
hap2016_2.insert(2, 'Year', 2016)

# %%
# Observe the result
hap2016_2.head()
# Out:
#        country          region  Year  happiness_rank  happiness_score  \
# 0      Denmark  Western Europe  2016               1            7.526
# 1  Switzerland  Western Europe  2016               2            7.509
# 2      Iceland  Western Europe  2016               3            7.501
# 3       Norway  Western Europe  2016               4            7.498
# 4      Finland  Western Europe  2016               5            7.413
#
#    economy_GDP_per_capita   family  health_life_expectancy  freedom  \
# 0                 1.44178  1.16374                 0.79504  0.57941
# 1                 1.52733  1.14524                 0.86303  0.58557
# 2                 1.42666  1.18326                 0.86733  0.56624
# 3                 1.57744  1.12690                 0.79579  0.59609
# 4                 1.40598  1.13464                 0.81091  0.57104
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                      0.44453     0.36171            2.73939
# ...

# %%
hap2016_2['Year'].value_counts(dropna=False)
# Out:
# 2016    157
# Name: Year, dtype: int64

# %%
# 2017 Using DataFrame.insert() to add a column
hap2017_2.insert(2, 'Year', 2017)

# %%
# Observe the result
hap2017_2.head()
# Out:
#        country          region  Year  happiness_rank  happiness_score  \
# 0       Norway  Western Europe  2017               1            7.537
# 1      Denmark  Western Europe  2017               2            7.522
# 2      Iceland  Western Europe  2017               3            7.504
# 3  Switzerland  Western Europe  2017               4            7.494
# 4      Finland  Western Europe  2017               5            7.469
#
#    economy_GDP_per_capita    family  health_life_expectancy   freedom  \
# 0                1.616463  1.533524                0.796667  0.635423
# 1                1.482383  1.551122                0.792566  0.626007
# 2                1.480633  1.610574                0.833552  0.627163
# 3                1.564980  1.516912                0.858131  0.620071
# 4                1.443572  1.540247                0.809158  0.617951
#
#    trust_government_corruption  generosity  dystopia_residual
# ...

# %%
hap2017_2['Year'].value_counts(dropna=False)
# Out:
# 2017    155
# Name: Year, dtype: int64

# %%
# 2018 Using DataFrame.insert() to add a column
hap2018.insert(2, 'Year', 2018)

# %%
# Observe the result
hap2018.head()
# Out:
#        country          region  Year  happiness_rank  happiness_score  \
# 0      Finland  Western Europe  2018               1            7.632
# 1       Norway  Western Europe  2018               2            7.594
# 2      Denmark  Western Europe  2018               3            7.555
# 3      Iceland  Western Europe  2018               4            7.495
# 4  Switzerland  Western Europe  2018               5            7.487
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.305   1.592                   0.874    0.681
# 1                   1.456   1.582                   0.861    0.686
# 2                   1.351   1.590                   0.868    0.683
# 3                   1.343   1.644                   0.914    0.677
# 4                   1.420   1.549                   0.927    0.660
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                        0.393       0.202                  0
# ...

# %%
hap2018['Year'].value_counts(dropna=False)
# Out:
# 2018    156
# Name: Year, dtype: int64

# %%
# 2019 Using DataFrame.insert() to add a column
hap2019.insert(2, 'Year', 2019)

# %%
# Observe the result
hap2019.head()
# Out:
#        country          region  Year  happiness_rank  happiness_score  \
# 0      Finland  Western Europe  2019               1            7.769
# 1      Denmark  Western Europe  2019               2            7.600
# 2       Norway  Western Europe  2019               3            7.554
# 3      Iceland  Western Europe  2019               4            7.494
# 4  Netherlands  Western Europe  2019               5            7.488
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.340   1.587                   0.986    0.596
# 1                   1.383   1.573                   0.996    0.592
# 2                   1.488   1.582                   1.028    0.603
# 3                   1.380   1.624                   1.026    0.591
# 4                   1.396   1.522                   0.999    0.557
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                        0.393       0.153                  0
# ...

# %%
hap2019['Year'].value_counts(dropna=False)
# Out:
# 2019    156
# Name: Year, dtype: int64

# %%
# 2020 Using DataFrame.insert() to add a column
hap2020_2.insert(2, 'Year', 2020)

# %%
# Observe the result
hap2020_2.head()
# Out:
#        country          region  Year  happiness_rank  happiness_score  \
# 0      Finland  Western Europe  2020               1           7.8087
# 1      Denmark  Western Europe  2020               2           7.6456
# 2  Switzerland  Western Europe  2020               3           7.5599
# 3      Iceland  Western Europe  2020               4           7.5045
# 4       Norway  Western Europe  2020               5           7.4880
#
#    economy_GDP_per_capita    family  health_life_expectancy   freedom  \
# 0                1.285190  1.499526                0.961271  0.662317
# 1                1.326949  1.503449                0.979333  0.665040
# 2                1.390774  1.472403                1.040533  0.628954
# 3                1.326502  1.547567                1.000843  0.661981
# 4                1.424207  1.495173                1.008072  0.670201
#
#    trust_government_corruption  generosity  dystopia_residual
# ...

# %%
hap2020_2['Year'].value_counts(dropna=False)
# Out:
# 2020    153
# Name: Year, dtype: int64

# %%
# 2021 Using DataFrame.insert() to add a column
hap2021_2.insert(2, 'Year', 2021)

# %%
# Observe the result
hap2021_2.head()
# Out:
#        country          region  Year  happiness_rank  happiness_score  \
# 0      Finland  Western Europe  2021               1            7.842
# 1      Denmark  Western Europe  2021               2            7.620
# 2  Switzerland  Western Europe  2021               3            7.571
# 3      Iceland  Western Europe  2021               4            7.554
# 4  Netherlands  Western Europe  2021               5            7.464
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.446   1.106                   0.741    0.691
# 1                   1.502   1.108                   0.763    0.686
# 2                   1.566   1.079                   0.816    0.653
# 3                   1.482   1.172                   0.772    0.698
# 4                   1.501   1.079                   0.753    0.647
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                        0.481       0.124              3.253
# ...

# %%
hap2021_2['Year'].value_counts(dropna=False)
# Out:
# 2021    149
# Name: Year, dtype: int64

# %%
# 2022 Using DataFrame.insert() to add a column
hap2022_2.insert(2, 'Year', 2022)

# %%
# Observe the result
hap2022_2.head()
# Out:
#        country          region  Year  happiness_rank happiness_score  \
# 0      Finland  Western Europe  2022               1           7,821
# 1      Denmark  Western Europe  2022               2           7,636
# 2      Iceland  Western Europe  2022               3           7,557
# 3  Switzerland  Western Europe  2022               4           7,512
# 4  Netherlands  Western Europe  2022               5           7,415
#
#   economy_GDP_per_capita family health_life_expectancy freedom  \
# 0                  1,892  1,258                  0,775   0,736
# 1                  1,953  1,243                  0,777   0,719
# 2                  1,936  1,320                  0,803   0,718
# 3                  2,026  1,226                  0,822   0,677
# 4                  1,945  1,206                  0,787   0,651
#
#   trust_government_corruption generosity dystopia_residual
# 0                       0,534      0,109             2,518
# ...

# %%
hap2022_2['Year'].value_counts(dropna=False)
# Out:
# 2022    145
# Name: Year, dtype: int64

# %% [markdown]
# #### 04. Exporting files

# %%
hap2015_2.to_csv(os.path.join(path, 'Prepared Data', 'wr2015.csv'))
hap2016_2.to_csv(os.path.join(path, 'Prepared Data', 'wr2016.csv'))
hap2017_2.to_csv(os.path.join(path, 'Prepared Data', 'wr2017.csv'))
hap2018.to_csv(os.path.join(path, 'Prepared Data', 'wr2018.csv'))
hap2019.to_csv(os.path.join(path, 'Prepared Data', 'wr2019.csv'))
hap2020_2.to_csv(os.path.join(path, 'Prepared Data', 'wr2020.csv'))
hap2021_2.to_csv(os.path.join(path, 'Prepared Data', 'wr2021.csv'))
hap2022_2.to_csv(os.path.join(path, 'Prepared Data', 'wr2022.csv'))
